# %%
import sys
sys.path.append('/home/logic/proj/roughset')


from logic.roughset.roughset import Roughset as rs
import pandas as pd

df = pd.read_csv('./test2.csv')
df
# Out:
#     U    Age   LEMS Walk
# 0  x1  16-30     50  yes
# 1  x2  16-30      0   no
# 2  x3  31-45   1-25   no
# 3  x4  31-45   1-25  yes
# 4  x5  46-60  26-49   no
# 5  x6  16-30  26-49  yes
# 6  x7  46-60  26-49   no

# %%
df.index = df['U']
df.drop(columns=['U'],inplace=True)
df
# Out:
#       Age   LEMS Walk
# U
# x1  16-30     50  yes
# x2  16-30      0   no
# x3  31-45   1-25   no
# x4  31-45   1-25  yes
# x5  46-60  26-49   no
# x6  16-30  26-49  yes
# x7  46-60  26-49   no

# %%
X = df[df['Walk'].str.contains('y')]
X
# Out:
#       Age   LEMS Walk
# U
# x1  16-30     50  yes
# x4  31-45   1-25  yes
# x6  16-30  26-49  yes

# %%
A = ['Age','LEMS']
r = rs(df,A).init().set_X(X)

# %%
r

# %%
r.lower
# Out:
# [['x6'], ['x1']]

# %%
r.upper
# Out:
# [['x6'], ['x1'], ['x3', 'x4']]

# %%
upper_list = rs.flatten_list(r.upper)
upper_list
# Out:
# ['x6', 'x1', 'x3', 'x4']

# %%
lower_list = rs.flatten_list(r.lower)
lower_list
# Out:
# ['x6', 'x1']

# %%
r.bn
# Out:
# ['x4', 'x3']

# %%
U = list(df.index)
U
# Out:
# ['x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7']

# %%
r.neg
# Out:
# ['x7', 'x2', 'x5']

# %%
r.knowledge
# Out:
# [['x2'], ['x6'], ['x1'], ['x3', 'x4'], ['x5', 'x7']]

# %%
r.pos
# Out:
# [['x6'], ['x1']]
